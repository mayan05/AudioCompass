# %%
# import subprocess
# import os
# import time

# for i in range(60,160,10):
#     if(i==90):
#         continue
#     else:
#         major_keys = ['C', 'D', 'E', 'F', 'G', 'A', 'B']
#         sharp_keys = ['C', 'D', 'F', 'G', 'A']
#         output_dir = f"E:/Coding/Projects/Multi-Task-Audio-Analyzer/tracks_tempo_&_key/tracks_{i}bpm_major"
#         os.makedirs(output_dir, exist_ok=True)

#         for key in major_keys:
#             query = f"{key} major backing track {i} bpm"
#             print(f"\n🔍 Searching and downloading: {query}")

#             output_template = os.path.join(output_dir, f"{key}_major_{i}.%(ext)s")

#             try:
#                 subprocess.run([
#                     "yt-dlp",
#                     f"ytsearch1:{query}",
#                     "-x", "--audio-format", "wav",
#                     "-o", output_template,
#                     "--no-playlist",
#                     "--quiet"
#                 ], check=True)

#                 print(f"✅ Downloaded: {key}_major_{i}.wav")
#                 time.sleep(2)  # Avoid rate limiting
#             except subprocess.CalledProcessError as e:
#                 print(f"❌ Failed for key: {key} — {e}")
            

#         for key in sharp_keys:
#             query = f"{key}# major backing track {i} bpm"
#             print(f"\n🔍 Searching and downloading: {query}")

#             output_template = os.path.join(output_dir, f"{key}#_major_{i}.%(ext)s")

#             try:
#                 subprocess.run([
#                     "yt-dlp",
#                     f"ytsearch1:{query}",
#                     "-x", "--audio-format", "wav",
#                     "-o", output_template,
#                     "--no-playlist",
#                     "--quiet"
#                 ], check=True)

#                 print(f"✅ Downloaded: {key}#_major_{i}.wav")
#                 time.sleep(2)  # Avoid rate limiting
#             except subprocess.CalledProcessError as e:
#                 print(f"❌ Failed for key: {key} — {e}")

# %%
# minor_keys = ['C', 'D', 'E', 'F', 'G', 'A', 'B']
# sharp_keys = ['C', 'D', 'F', 'G', 'A']
# failed_log = "minor_failed_downloads.log"

# for bpm in range(50, 160, 10):
    
#     output_dir = f"E:/Coding/Projects/Multi-Task-Audio-Analyzer/tracks_tempo_&_key/tracks_{bpm}bpm_minor"
#     os.makedirs(output_dir, exist_ok=True)

#     for key in minor_keys + [k + "#" for k in sharp_keys]:
#         query = f"{key} minor backing track {bpm} bpm"
#         output_template = os.path.join(output_dir, f"{key}_minor_{bpm}.%(ext)s")

#         print(f"\n🔍 Downloading: {query}")
#         success = download_track(query, output_template)

#         if success:
#             print(f"✅ Downloaded: {key}_minor_{bpm}.wav")
#         else:
#             print(f"❌ Failed after retries: {query}")
#             with open(failed_log, "a") as f:
#                 f.write(f"{query}\n")

#         time.sleep(random.randint(3, 7))

# %%
import os
import time
import random
import subprocess

download_root = "ElevatedTracks"
playlist_file = "playlist.txt"

os.makedirs(download_root, exist_ok=True)

def load_playlists():
    with open(playlist_file) as f:
        urls = [line.strip() for line in f if line.strip()]
    print(f"✅ Found {len(urls)} playlists.")
    return urls

def download_playlist(url):
    print(f"⬇️ Downloading audio from: {url}")
    cmd = [
        "yt-dlp",
        # "--extractor-args", "youtube:player_client=web",
        # "--retries", "3", 
        "-x",  # extract audio
        "--audio-format", "mp3",  # or wav/m4a if you prefer
        "-o",
        os.path.join(download_root, "%(playlist)s", "%(title)s.%(ext)s"),
        url,
    ]
    subprocess.run(cmd, check=True)
    time.sleep(random.randint(10, 20))  # polite pause

if __name__ == "__main__":
    playlists = load_playlists()
    for url in playlists:
        try:
            download_playlist(url)
        except subprocess.CalledProcessError:
            print(f"❌ Failed: {url}")
# Out:
# ✅ Found 49 playlists.
# ⬇️ Downloading audio from: https://www.youtube.com/playlist?list=PLU6rw98nc2Jqst_QCXhVF7yykQo4kOnWq
# ❌ Failed: https://www.youtube.com/playlist?list=PLU6rw98nc2Jqst_QCXhVF7yykQo4kOnWq
# ⬇️ Downloading audio from: https://www.youtube.com/playlist?list=PLU6rw98nc2JpSmGgBUko1wTctTmSeTJUU
